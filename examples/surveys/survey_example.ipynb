# %%
import json
from uuid import uuid4
from open_aglabs.surveys.models import SurveyDataModel

# %%
id = str(uuid4())
data_dict = {
    "path": f"test/{id}.json",
    "id": id,
    "collection_date": "2025-09-30",
    "trial_properties": {"name": "maize_variety_survey_2025"},
    "agronomic_properties": {"crop_type": "corn"},
    "protocol_properties": {"name": "crop_survey_v2.0"},
    "location_properties": {"site": "Example Site",
                            "field": "Field_1B",
                            "location": "a"},
    "answers": {"Q1": {"question": "What is the yield?",
                       "answer": "20 tons"}},
    "followups": {"Q1": {"question": "Is that tons per field or tons / ha",
                       "answer": "tons/ha"}},
    "voice_files": [{ "path": "voice_clip.mp3",
                      "id": str(uuid4()),
                      "question": "Q1",
                      "answer": ""}],
    "image_files": [{ "path": "voice_clip.mp3",
                      "id": str(uuid4()),
                      "question": "Q1"}],
    "notes": []
}

# %%
model = SurveyDataModel(**data_dict)

# %%
print(model)
# Out:
# path='test/c2bbaddc-ee89-4552-947b-6e56c3a4a0aa.json' id='c2bbaddc-ee89-4552-947b-6e56c3a4a0aa' collection_date='2025-09-30' trial_properties=TrialProperties(id=None, name='maize_variety_survey_2025') protocol_properties=ProtocolProperties(name='crop_survey_v2.0', id=None, url=None) location_properties=Location(id=None, name=None, latitude=None, longitude=None, elevation_m=None, crs=None, geometry=None, admin_level_0=None, admin_level_1=None, admin_level_2=None, admin_level_3=None, site='Example Site', grower=None, farm=None, field='Field_1B', location='a') agronomic_properties=AgronomicProperties(crop_type='corn', growth_stage=None, soil_color=None, weed_pressure=None, irrigation_level=None, tillage_type=None, fertilizer_level=None) answers={'Q1': QuestionAnswer(question='What is the yield?', answer='20 tons')} followups={'Q1': QuestionAnswer(question='Is that tons per field or tons / ha', answer='tons/ha')} voice_files=[VoiceFile(path='voice_clip.mp3', id='ec776615-41eb-42f2-b079-2
# ...
